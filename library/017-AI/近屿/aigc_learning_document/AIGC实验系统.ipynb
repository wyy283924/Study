# %% [markdown]
# # AIGC实验系统声明
#
# AIGC实验系统指发放给学员使用服务器A800资源的账户。
#
# 1. 账户会根据课程的内容限时发放，足够完成实践内容。
# 2. 服务器只可用于学习用途，且仅限学习《AIGC大模型培训》课程的内容，不可用来运行与课程无关的代码，不可上传/下载非本课程提供的数据。如有违反，账号随时会被封禁
# 3. 在服务器编写代码，请做好备份，以防服务器出现问题。
# 4. 在服务器上完成的实践结果，请及时保存备份到本地。
