# %% [markdown]
# # A2

# %% [markdown]
# ## A2.0 Python之提示工程基础 2学时
# - 什么是python
# - python文件的创建和运行(变量、函数、面向对象编程、成品展示)

# %% [markdown]
# ## A2.1 大模型提示工程 2学时
# - A2.1.1 Chat GPT的诞生与发展
# - A2.1.2 大语言模型的应用架构
# - A2.1.3 与大模型日常交互
# - A2.1.4 Prompt工程简介
# - A2.1.5 Prompt的设计与优化方法
# - A2.1.6 使用Prompt完成自定义任务
# - A2.1.7 Prompt工程示例及实践
# - A2.1.8 自动化Prompt工程

# %% [markdown]
# ## A2.2 大模型编程 2学时
# - A2.2.1 大模型编程的特点及应用场景
# -
# A2.2.2 编程大模型样
# - A2.2.3 影响编程大模型性能的因素
# - A2.2.4 大模型编程实际应用
# - A2.2.5 使用大模型编程的技巧与注意事项
# - A2.2.6 编程大模型的趋势分享的趋势分享

# %% [markdown]
# ## A2.3 大模型的API及Plugins调用 2学时
# - A2.3.1 Prompt 工程回顾（简单prompt设计、组件式prompt设计）
# - A2.3.2 大语言模型性能评估与比较
# - A2.3.3 使用Python调用各类大语言模型的API（百度文心一言、星火大语言模型、OpenAI、使用OneApi统一调用）
# - A2.3.4 大模型额外能力调用（ 函数调用、Assistant API）

# %% [markdown]
# ## A2.4 远程实践项目+爬梯考试

# %% [markdown]
# ## A2.5 大模型的发展历程 2学时（选修）
# - A2.5.1大模型概览
# - A2.5.2 实用案例分析
# - A2.5.3 大语言模型深入解析
# - A2.5.4 大模型的挑战与未来与未来

# %% [markdown]
# ## A2.6 GPT4-Turbo与Gemini最新解读 2学时（选修）
# - A2.6.1 GPT-4V和Gemini的基本介绍
# - A2.6.2 技术架构
# - A2.6.3 GPT4-V相关技术
# - A2.6.4 Gemini相关概述
# - A2.6.5 Gemini Pro - GPT-4V 的评测对比
# - A2.6.6 CMU评测：关于Gemini造假风波

# %% [markdown]
# # A3

# %% [markdown]
# ## A3.1	大模型RAG
# - A3.1.1 RAG的由来
# - A3.1.2 RAG示例
# - A3.1.3 RAG在大模型优化的位置
# - A3.1.4 RAG各组件优化方案
# - A3.1.5 RAG 的优缺点
# - A3.1.6 RAG能力评估
# - A3.1.7 RAG系统常见的问题以及解决方案
# - A3.1.8 大模型RAT
#
# ## A3.2 LangChain & Semantic Kernel原理
# - A3.2.1 LangChain、SK 技术原理，工作流程，组件分析与探索
# - A3.2.2 LangChain与SK对比
# - A3.2.3 GPTs最新相关解读和对比
# - A3.2.4 Semantic Functions, Semantic Kernel Tools等Memory, Pipline,Planner等
# ## A3.3	LangChain & Semantic Kernel实战
# - A3.3.1 LangChain实战
# - A3.3.2 Semantic Kernel 实战
# ## A3.4	AutoGen原理
# - A3.4.1 多智能体系统概述
# - A3.4.2 AutoGen框架
# ## A3.5 AutoGen实战
# - A3.5.1 检索聊天（使用RetrieveChat进行检索增强代码生成和问答	、 RetrieveChat实例、定制RetrieveUserProxyAgent）
# - A3.5.2 教会大模型新的技能：TeachableAgent
# - A3.5.3 自动构建的多智能体系统：AuTo Build
# - A3.5.4 使用代码解释器的GPTAssistant
# - A3.5.5 再探群聊（使用select_speaker实现多层次的信息流、使用图结构建模聊天路径）ner等

# %% [markdown]
# ## A3.6 远程实践项目+爬梯考试

# %% [markdown]
# # A4

# %% [markdown]
# ## A4.1 大模型开发环境及工具 2学时
# - A4.1.1 开发环境的基本要求
# - A4.1.2 搭建步骤与配置
# - A4.1.3 大模型特定工具与库的使用
# - A4.1.4 微调示例
# ## A4.2 大模型微调 2学时
# - A4.2.1 大模型微调简介
# - A4.2.2 微调示例
# - A4.2.3 微调模型的数据准备
# - A4.2.4 微调在大模型训练中的位置
# - A4.2.5 PEFT方法对比
# ## A4.3 大模型微调实战 2学时
# - A4.3.1 实战
# - A4.3.2 大模型训练、推理优化方案
# - A4.3.3 大模型占用显存预估方法
# ## A4.4 大模型思维链 2学时
# - A4.4.1 什么是思维链
# - A4.4.2 思维链体系（CoT Self Consistency, Auto-CoT, Least to Most）
# - A4.4.3 思维链变种 (EoT, AoT, Sot, Xot, Cumulative Reasoning)
#
# ## A4.5 大模型结构解析 2学时
# - A4.5.1 大语言模型的发展历程
# - A4.5.2 GPT模型及其他主流语言模型简介
# - A4.5.3 语言模型结构深入分析
# ## A4.6 深度学习基础与实战 2学时
# - A4.6.1 为什么要学这门课
# - A4.6.2 什么是语言模型
# - A4.6.3 统计语言模型实战
# - A4.6.4 NLP的基础任务
# - A4.6.5 神经网络模型
# - A4.6.6 MNIST手写数字数据集分类实战
# - A4.6.7 自然语言处理任务的典型模型介绍
# - A4.6.8 模型选择与应用
# ## A4.7 Transformer原理  2学时
# - A4.7.1 词向量
# - A4.7.2 各类注意力机制
# - A4.7.3 Transformer
# - A4.7.4 Bert模型介绍与微调
#
# ## A4.8 远程实践项目+爬梯考试
#
#
# ## A4.9 Stable Diffusion 2学时（选修）
# - A4.9.1 引言：认识扩散模型
# - A4.9.2 Stable Diffusion模型及其生成能力
# - A4.9.3 Stable Diffusion模型的典型微调方法
# - A4.9.4 基于扩散模型的视频生成
