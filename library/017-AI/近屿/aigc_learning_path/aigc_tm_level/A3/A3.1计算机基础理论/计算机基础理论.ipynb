# %% [markdown]
# # 计算机基础理论
#
#
# - 1.计算机的组成和原理
# - 2.系统路径
# - 3.文件系统及格式
# - 4.环境变量
# - 5.人机交互
# - 6.软件系统间的交互API
# - 7.开发工具简介

# %% [markdown]
# **课程目标**
#
# - 掌握基础计算机的构成和原理
# - 理解计算机及软件和网络通信(API开发和计算机网络基础)
#
#
# **上课前完成的基础环境工具安装：**
#
# - Windows：Xshell、Xftp、Git、postman、Vscode、python3.10以上
# - Mac：Nex Terminal、Git、postman、Vscode、python3.10以上
#
#
# ## 一、计算机的组成和原理
#
# ### 1.计算机的硬件组成
#
# <img src="./images/1.png" width = "600" alt="图片名称" align=center />
#
# **功能分类视角**
# ‌
# 1. 运算器与控制器‌：集成于CPU，分别负责数据运算和指令协调。‌‌
# 2. ‌存储器‌：分为内存（临时存储）和外存（长期存储）。‌‌
# 3. ‌输入/输出系统‌：如扫描仪、打印机等，扩展计算机功能。‌‌
#
#
#
# 计算机的硬件组成主要包括中央处理器（CPU）、内存（RAM）、存储设备（硬盘/SSD）、主板、电源、**输入设备**（如键盘、鼠标）和**输出设备**（如显示器）等核心部件。
#
#  **核心硬件组件**
#   ‌
# 1. ‌**中央处理器（CPU）**‌：作为计算机的“大脑”，负责执行指令和运算，其性能直接影响整体运行速度。主流品牌包括Intel和AMD。‌‌
# 2. ‌**内存（RAM）**‌：内存是计算机中与CPU直接沟通的关键部件，用于暂时存放CPU的运算数据以及与硬盘等外部存储器交换的数据。存储运行中的程序和数据，容量越大，多任务处理能力越强。日常使用建议8GB起步，专业需求建议16GB以上。‌‌
# 3. ‌**存储设备**‌：
# * 机械硬盘（HDD）：容量大、成本低，但速度较慢。
# * 固态硬盘（SSD）：读写速度快，耐用性高，适合安装操作系统。‌‌
# 4. ‌**主板**‌：连接所有硬件的枢纽，决定兼容性和扩展性，需根据CPU和显卡选择匹配型号。‌‌
# 5. ‌**电源**‌：为硬件提供稳定电力，需根据整机功耗选择功率。
#
#   ‌‌
# **辅助与外设组件**
#   ‌
# 1. ‌**显卡（GPU）**‌：是一种用于处理图像和图形运算工作的处理器。图像处理等应用领域提供了高逼真的渲染效果，在科学计算等研究领域提供了强大的计算能力。
# * 集成显卡：适合日常办公。
# * 独立显卡：适合游戏、设计等高负载任务，如NVIDIA GeForce系列。‌‌
# 2. ‌**散热系统**‌：包括风冷和水冷，防止硬件过热，高性能电脑建议水冷。‌‌
# 3. ‌**输入/输出设备**‌：键盘、鼠标、显示器等，实现人机交互。‌‌
#
#
#
# ### 2.计算机的三大功能要素，计算、存储、网络/通信
#
# - 计算：负责指令执行与数据处理，通常讲CPU，现在计算系统还包括GPU、FPGA等专用计算单元。
# - 存储‌：分为内存（主存）和存储器（外存），形成层次化结构（如寄存器 、高速缓存、固态硬盘)。
# - 网络：体现在计算机的网卡，用于和外部设备、系统进行相互的通信，常见的如浏览器访问网络资源，各种应用客户端。
#
#
#
# ### 3.计算机的软件
#
# - 硬件固件：BIOS
# - 系统软件：操作系统 Windows、MacOS、Linux、IOS、Android ；文件管理系统NTFS、FAT32、APFS
# - 应用软件：浏览器、Office、微信客户端、App、数据库系统
#
#
# <img src="./images/2.png" width = "600" alt="图片名称" align=center />
#
#
# 软件都是从外部存储加载到内存，在外部存储中有特定的位置，我们称之为路径。
#
# **教学：**
#
# 按照定义和示意图讲解，列举常用计算机行为和知识点对应，介绍存储和路径概念。
#
# ## 二、系统路径
#
#
# ### 1.相对路径和绝对路径
#
# **绝对路径：**
#
# 是指文件或目录在文件系统中的完整位置描述，它从根目录开始，依次列出所有经过的目录和文件名，直到目标文件。
#
# 在不同的操作系统中，根目录的表示有所不同。
#
# 例如，在 Windows 系统中，通常以盘符（如 C:、D: 等）作为根目录，像 C:\Users\Admin\Documents\file.txt 就是一个指向 file.txt 文件的绝对路径；/Users/app/Downloads/sogou_mac_new_guanwang_618c.app
#
# 而在类 Unix 系统（如 Linux、Mac OS）中，根目录用 / 表示，如 /home/user/Documents/file.txt。
#
# 在 Web 开发中，绝对路径是指从网站的根域名开始的完整 URL 地址。例如，对于一个域名为 www.example.com 的网站，如果有一张图片位于 images/logo.png，其在网页中的绝对路径可能是 [https://www.example.com/images/logo.png](https://www.example.com/images/logo.png)。这种路径提供了一个精确且固定的位置指向，无论在什么环境下，只要域名不变，就能准确找到对应的资源。
#
#
#
# **相对路径：**
#
# 是基于当前所在的工作目录或文件位置来描述目标文件或目录的路径。它不依赖于根目录，而是通过与当前位置的相对关系来定位。
#
# 比如，当前目录下有一个子目录 subfolder，里面有一个文件 data.txt，若当前工作目录为父目录，那么指向 data.txt 的相对路径就是 subfolder/data.txt。
#
# 在网页开发场景下，相对路径是以当前网页所在的目录为基准。假设当前网页 index.html 与 images 文件夹处于同一层级，且 images 文件夹内有一张图片 pic.jpg，在 index.html 中引用该图片的相对路径就是 images/pic.jpg。相对路径的灵活性在于，只要文件的相对位置关系不变，即使整个项目被移动到其他部位，链接依然有效。
#
# ### 2.window mac linux 应用
#
# #### 2.1实例：
#
# **windows：**
#
# 绝对路径：c:\window\ c:\Program Files
#
# 相对路径：./cmd.exe   **<font style="color:#DF2A3F;">..(上一级目录)</font>**
#
#       常用目录：c:\window c:\Program Files c:\Users\user c:\Users\user\AppData\
#
#
#
# **macOS:**
#
# 绝对路径：/User/app/
#
# 相对路径：./(当前目录)  **<font style="color:#DF2A3F;">..(上一级目录)</font>**
#
# 常用目录：
#
#
#
# **Linux：**
#
# 绝对路径：/usr/local /usr/bin /etc /mnt /home/
#
# 相对路径：./(当前目录)  **<font style="color:#DF2A3F;">..(上一级目录)</font>**
#
# 常用目录：/usr/local /usr/bin /etc /mnt /home/
#
#
#
#
# **2.2如何获取路径：**
#
# window：地址栏，命令行
#
# macOS：finder，Terminal
#
# Linux：Terminal pwd
#
#
#
# **注意点：**
#
# 1.关注路径名称中的空格或中文字符，可能会对应用带来一定的影响，可以作为排查的一个检查项目。
#
# 2.路径分隔符的正反向斜杠。
#
# 3.对于特定环境的斜杠转义。

# %% [markdown]
# ## 三、文件系统及格式
#
#
# ### 1.文件系统：
#
# 操作系统中负责管理、组织文件信息的软件称为文件管理系统，简称文件系统。
#
# 文件系统的职责是组织、管理和抽象物理存储，为用户和应用程序提供一种方便、高效、安全的文件存取方式。
#
# 文件系统是操作系统用于明确存储设备（常见的是磁盘，也有基于NAND Flash的固态硬盘）或分区上的文件的方法和数据结构；即在存储设备上组织文件的方法。
#
# 从系统角度来看，文件系统是对文件存储设备的空间进行组织和分配，负责文件存储并对存入的文件进行保护和检索的系统。具体地说，它负责为用户建立文件，存入、读出、修改、转储文件，控制文件的存取，当用户不再使用时撤销文件等。
#
#
#
# ### 2.文件类型分类：文本文件、二进制文件 可执行文件、动态库文件、特定格式文件
#
# - window常用文件的扩展名来区分文件类型，如.txt,.exe,.jpg,.bat,.dll
# - linux文件类型可以依据文档的权限来判断
#
# | 文件系统特性       | 主要操作系统支持                                    | 最小扇区 (字节) | 最大扇区 (字节)      | 最大单一文件          | 最大格式化容量          | 日志功能             | 主要设计用途                     |
# |-----------------|-----------------------------------------------------|---------------|---------------------|-----------------------|-------------------------|----------------------|----------------------------------|
# | FAT32 (FAT)     | 几乎所有 (Win, macOS, Linux, 游戏机, 安卓等)          | 512           | 32768               | ~4 GiB                | ~2 TiB                  | 否                   | 早期Windows、U盘、闪存卡           |
# | NTFS            | Win 默认, macOS (只读¹), Linux (读写)                | 512           | 4096 (64K NTFS3.1+) | ~16 EiB (理论)        | ~256 TB (Win), ~16 EiB (理论) | 是                   | Windows系统盘、大容量硬盘         |
# | CDFS (ISO 9660) | 几乎所有 (作为光盘标准)                              | 2048          | 2048                | 8 TiB (Level 3)       | ~2 TB (每个Session)      | 否                   | 光盘 (CD, DVD)                   |
# | exFAT           | Win (XP+), macOS (10.6.4+), Linux (需驱动)           | 512           | 32768               | ~16 EiB (理论)        | ~64 ZiB (理论)           | 否 (但支持事务化)      | 大容量闪存设备 (U盘、SD卡)        |
# | ext4 (ext*)     | Linux 默认, macOS (只读), Win (需第三方软件)         | 1024          | 4096                | ~16 TiB (for 4K block) | ~1 EiB (for 4K block)    | 是                   | Linux系统盘和数据盘               |
# | ZFS             | Solaris, FreeBSD, Linux (FUSE/ZoL), macOS (只读)     | 可变 (通常512) | 可高达 1M           | ~16 EiB               | ~256 万亿 YiB (理论)     | 是 (写时复制)         | 企业级服务器、数据存储             |
# | HFS             | Classic Mac OS                                      | 512           | 32768               | 2 GiB                 | 2 TB                    | 否                   | 旧款Mac系统盘                    |
# | HFS+            | macOS (10.0-10.12)                                  | 512           | 32768               | ~8 EiB                | ~8 EiB (理论)           | 是 (可选)             | 旧款Mac系统盘 (APFS前)           |
#
#
#
# **教学：**
#
# U盘格式化展示，linux fdisk，linux文件类型
#
# ## 四、环境变量
#
# ### 1.什么是环境变量及作用
#
# 环境变量（environment variables）一般是指在操作系统中用来指定操作系统运行环境的一些参数，如：临时文件夹位置和系统文件夹位置等。
# 环境变量是在操作系统中一个具有特定名字的对象，它包含了一个或者多个应用程序所将使用到的信息。例如Windows和DOS操作系统中的path环境变量，当要求系统运行一个程序而没有告诉它程序所在的完整路径时，系统除了在当前目录下面寻找此程序外，还应到path中指定的路径去找。用户通过设置环境变量，来更好的运行进程。
#
#
#
# ### 2.环境变量的设置 window linux、
#
# - window常用环境变量
#
# %ALLUSERSPROFILE% 局部 返回所有“用户配置文件”的位置。
#
# %APPDATA% 局部 返回默认情况下应用程序存储数据的位置。
#
# %CD% 局部 返回当前目录字符串。
#
# %CMDCMDLINE% 局部 返回用来启动当前的 Cmd.exe 的准确命令行。
#
# %CMDEXTVERSION% 系统 返回当前的“命令处理程序扩展”的版本号。
#
# %COMPUTERNAME% 系统 返回计算机的名称。
#
# %COMSPEC% 系统 返回命令行解释器可执行程序的准确路径。
#
#
# - linux常用环境变量
#
# 查看 /etc/profile
#
# PATH=$PATH:/usr/qa/tools/bin
#
# ENV==$HOME/.bashrc
#
# ORACLE_HOME=/dbs/oracle
#
# ORACLE_SID=qadb
#
#
# - 设置方法
#
# gui：在windows操作系统中可以通过我的电脑-〉系统属性-〉高级系统设置-〉环境变量，来设置系统的环境变量
#
# cmd：set PATH=%PATH%;d:\xxx
#
# 在linux中通过编辑etc/profile, .bshrc文件，永久生效
#
# 临时设置 export PATH=$PATH:/usr/bin
#
# **教学：**
#
# 通过是否设置环境变量来展示可执行文件的执行方式差异，及env讲解
#
# ## 五、人机交互
#
#
# ### 1.基础指令
#
# **echo、ls/dir、cd、pwd、mkdir、cp、mv、ping、rm、   touch、vi、cat、tail**
#
# - 运行环境：在window上打开cmd窗口，在linux/macOS上打开Terminal(终端)
# - 通用规则：命令 + 参数 之间用空格分隔，参数分为option(选项参数)和param(变量参数)
# - 查看帮助：man + 命令 之间用空格分隔，命令 -|--h|help
#
# #### 1.1 echo:
#
# **作用**：用于输出变量的内容或输出相应的文本
#
# **用法**：echo + 直接输出内容，echo + %|$变量名称
#
# #### 1.2 ls/dir
#
# **作用**：查看文件列表，ls用于linux，dir用于windows
#
# **用法**：命令 + option + param, ls -al ./; ls -al /etc
#
# #### 1.3 cd
#
# **作用**：<font style="color:rgb(0, 0, 0);">切换目录(路径)</font>
#
# **用法**：命令 + param cd ..; cd /usr/local;  cd ..; cd ../.. ; cd -; cd /; cd
#
# #### 1.4 pwd
#
# **作用：**显示当前目录(路径)
#
# **用法：**命令 pwd
#
# #### 1.5 mkdir
#
# **作用**：<font style="color:rgb(0, 0, 0);">创建目录或是创建新文件夹</font>
#
# **用法**：命令 + option + param mkdir a3; mkdir -p a3/suba3
#
# #### 1.6 cp
#
# **作用**：拷贝目录/文件
#
# **用法**：命令 + option + param  cp -a old_dir new_dir
#
# #### 1.7 mv
#
# **作用：**移动目录/文件
#
# **用法：**命令 + option + param mv old_dir new_dir
#
# #### 1.8 rm
#
# **作用**：删除目录/文件
#
# **用法**：命令 + option + param rm -f file1; rm -rf dir1; rm -rf dir1 dir2
#
# #### 1.9 ping
#
# **作用**：测试网络联通性
#
# **用法**：命令 + option + param ping 目标地址(IP或域名)
#
#
#
# #### 1.10 touch
#
# **作用**：创建空文件
#
# **用法**：命令 + param touch file1
#
# #### 1.11 vi
#
# **作用**：文本编辑器
#
# **用法**：命令 + param vi file1(<font style="color:#DF2A3F;">要编辑的文件名称,需要对文件有读写权限，文件可以带上相对/绝对路径</font>)
#
# #### 1.12 cat
#
# **作用**：输出文件到终端Shell
#
# **用法**：命令 + param cat file1
#
# #### 1.13 tail
#
# **作用**：输出文件的尾部内容到终端
#
# **用法**：命令 + option + param tial -f file1
#
#
#
#
#
# ### 2.进阶用法
#
# 重定向、管道、查找(which,find)、历史操作
#
# #### 2.1 > >>
#
# **作用**：将输出重定向到新对象（可以接收输出的对象，如终端、文件等）
#
# **用法**：cat file > file1
#
# #### 2.2 which
#
# **作用**：查找是否存在某个命令
#
# **用法**：命令 + 需要查找的命令 which cat
#
# #### 2.3 find
#
# **作用**：查找指定的文件
#
# **用法**：命令 + option + param    find / -name 'file*'
#
# #### 2.4 history
#
# **作用**：查看历史执行操作命令
#
# **用法**：history    结合管道more
#
#
#
# **教学：**
#
# 每个命令实操，讲解命令的目标，使用条件，操作结果

# %% [markdown]
# ## 六、软件系统间的交互API
#
#
# ### 1.应用程序接口，系统函数接口
#
# API，全称是应用程序编程接口（Application Programming Interface），是软件组件之间信息交互的桥梁，简单来说API就是让不同的软件系统能够相互“对话”的工具。
#
# API主要分为两类：
#
# 一个是一些预先定义的函数，目的是提供应用程序与开发人员基于某软件或硬件得以访问一组例程的能力，而又无需访问源码，或理解内部工作机制的细节。是同语言系统接口，使用的方式是相应的开发语言引入对应的函数库，通过函数名及参数来调用，可以通过语言的编译器或解释执行环境来运行。
# 一个是基于跨语言跨平台的方式，提供编程接口的系统将自己的能力通过网络的方式提供。
#
# ### 2.开放系统应用互联接口 HTTP、TCP、UDP
#
# 为了更好地理解 API，我们可以把它拆解成几个关键部分，每个部分都有其重要作用。这里我列举几个主要组成部分，并用简单的例子来解释它们：
# - Application（应用程序）：API 是应用程序的一部分，它允许其他程序与它进行交互。
# - Protocol （协议）：规定两个端之间的传输应该遵从什么规则，常见的协议有 HTTP、HTTPS 等。就像我们说话需要遵循语法和词汇，API 通信也需要遵守这些协议。除了HTTP，还有很多基于TCP、UDP等传输层协议来承载的API，这部分更多的是应用于分布式中间件。
# - Interface（接口）：可以类比为银行中的窗口，不用接口对应不同的服务窗口。
# - Format（格式）：两个端之间传输的介质，比如 JSON/XML
#
#
# ### 3.基于HTTP的交互，方法、状态码、消息体
#
# **定义：**
#
# HTTP（超文本传输协议）和HTTPS（超文本传输安全协议）是互联网中用于数据传输的两种主要协议。它们在功能上相似，但在安全性方面有本质的区别。
#
# HTTP是一种无状态的协议，不保留之前的每何请求或响应的状态信息。它基于TCP/P协议，通常使用80端口。HTTP协议的数据传输是不加密的，这意味着所有传输的内容都是明文，容易被第三方截获和篡改。因此，HTTP不适合传输敏感信息，如信用卡号码或密码。
#
# HTTPS是HTTP的安全版本，它在HTTP的基础上通过SSLTLS协议提供了数据加密、完整性校验和身份验证。这些功能确保了数据在传输过程中不会被截获或纂改，并验证了服务器的身份。
#
# HTTPS通常使用443端口。
#
# HTTP（超文本传输协议，HyperText Transfer Protocol）是一种用于分布式、协作式、超媒体信息系统的应用层协议。
#
# HTTP 是万维网（WWW）的数据通信的基础，设计目的是确保客户端与服务器之间的通信，是互联网上最常用的协议之一。
#
# HTTP 是一个基于 TCP/IP 通信协议来传递数据的（HTML 文件、图片文件、查询结果等）。
#
# 设计 HTTP 最初的目的是为了提供一种发布和接收 HTML 页面的方法，通过 HTTP 或者 HTTPS 协议请求的资源由统一资源标识符（Uniform Resource Identifiers，URI）来标识。
#
# #### HTTP工作方式原理：
#
# HTTP 的基本工作原理是客户端（通常是 web 浏览器）向服务器发送请求，服务器接收到请求后，返回相应的资源。这些资源可以是网页、图像、音频文件、视频等。
#
# HTTP 使用了客户端-服务器模型，其中客户端发送请求，服务器返回响应。
#
# <img src="./images/3.png" width = "600" alt="图片名称" align=center />
#
# 每个请求都是独立的，服务器不会记住之前的请求。基于会话无状态。
#
#
# <img src="./images/4.png" width = "600" alt="图片名称" align=center />
#
#
#
# #### HTTP工作步骤：
#
# - 建立连接：客户端与服务器之间建立连接。在传统的 HTTP 中，这是基于 TCP/IP 协议的。最近的 HTTP/2 和 HTTP/3 则使用了更先进的传输层协议，例如基于 TCP 的二进制协议（HTTP/2）或基于 UDP 的 QUIC 协议（HTTP/3）。
# - 发送请求：客户端向服务器发送请求，请求中包含要访问的资源的 URL、请求方法（GET、POST、PUT、DELETE 等）、请求头（例如，Accept、User-Agent）以及可选的请求体（对于 POST 或 PUT 请求）。
# - 处理请求：服务器接收到请求后，根据请求中的信息找到相应的资源，执行相应的处理操作。这可能涉及从数据库中检索数据、生成动态内容或者简单地返回静态文件。
# - 发送响应：服务器将处理后的结果封装在响应中，并将其发送回客户端。响应包含状态码（用于指示请求的成功或失败）、响应头（例如，Content-Type、Content-Length）以及可选的响应体（例如，HTML 页面、图像数据）。
# - 关闭连接：在完成请求-响应周期后，客户端和服务器之间的连接可以被关闭，除非使用了持久连接（如 HTTP/1.1 中的 keep-alive）。
#
#
# #### HTTP工作方法：
#
# HTTP 方法指定了客户端可以对服务器上的资源执行哪些动作。
# 主要的HTTP方法有：
# - GET：请求从服务器获取指定资源。这是最常用的方法，用于访问页面。
# - POST：请求服务器接受并处理请求体中的数据，通常用于表单提交。
# - PUT：请求服务器存储一个资源，并用请求体中的内容替换目标资源的所有内容。
# - DELETE：请求服务器删除指定的资源。
# - HEAD：与 GET 类似，但不获取资源的内容，只获取响应头信息。
#
# #### HTTP状态码：
#
# HTTP状态码是服务器对客户端请求的响应。
#
# 状态码分为五类：
# - 1xx（信息性状态码）：表示接收的请求正在处理。
# - 2xx（成功状态码）：表示请求正常处理完毕。
# - 3xx（重定向状态码）：需要后续操作才能完成这一请求。
# - 4xx（客户端错误状态码）：表示请求包含语法错误或无法完成。
# - 5xx（服务器错误状态码）：服务器在处理请求的过程中发生了错误。
#
# #### HTTP版本：
#
# HTTP 有多个版本，目前广泛使用的是 HTTP/1.1 和 HTTP/2，以及正在逐步推广的 HTTP/3。
# - HTTP/1.1：支持持久连接，允许多个请求/响应通过同一个 TCP 连接传输，减少了建立和关闭连接的消耗。
# - HTTP/2：基于二进制分帧，支持多路复用，允许同时通过单一的 HTTP/2 连接发起多重的、独立的、双向的交流。
# - HTTP/3：基于 QUIC 协议，旨在减少网络延迟，提高传输速度和安全性。
#
# 消息体：返回内容
#
#
#
# ### 4.json语法
#
# JSON（JavaScript Object Notation，JavaScript对象表示法）是基于ECMAScript的一个子集设计的，是一种开放标准的文件格式和数据交换格式，它易于人阅读和编写，同时也易于机器解析和生成。JSON独立于语言设计，很多编程语言都支持JSON格式的数据交换。JSON是一种常用的数据格式，在电子数据交换中有多种用途，包括与服务器之间的Web应用程序的数据交换。其简洁和清晰的层次结构有效地提升了网络传输效率，使其成为理想的数据交换语言。其文件通常使用扩展名.json。
#
# 1.数据结构对象（Object）一个无序的键值对集合。使用花括号“{}”包围。每个键值对由一个键和一个值组成，键和值之间用冒号“:”分隔，键值对之间用逗号“,”分隔。键必须是字符串，并且用双引号""包围。值可以是字符串、数值、布尔值、数组、对象或“null”。示例： {"name": "John","age": 30,"isStudent": false}数组（Array） 一个有序的值的集合。 使用方括号 “[]”包围。 值之间用逗号“,”分隔。 ["apple","banana", "cherry"]
#
# 2.值类型
# - 2.1字符串（String） 使用双引号 "" 包围。 可以包含转义字符，如 \" 表示双引号，\\ 表示反斜杠，\n 表示换行。 如："hello"数值（Number）
# - 2.2整数或浮点数。 不需要引号包围。 如：42，3.14
# - 2.3布尔值（Boolean） 表示 true 或 false。
# - 2.4空值（Null） 表示空值，用关键字 null 表示。
# - 2.5对象 子json格式。
# - 2.6数组用[ ]包围，里面的包含的元素可以是任意类型
# 3.示例以下是一个包含各种类型和结构的JSON示例：
#
# {
# 	"title": "JSON Example",
#
# 	"author": {
# 		"name": "John Doe",
# 		"age": 35,
# 		"isVerified": true
# 	},
# 	"tags": ["json", "syntax", "example"],
# 	"rating": 4.5,
# 	"isPublished": false,
# 	"comments": null
# }
#
# 4.注意事项键和值：键必须是字符串，并且用双引号包围。值可以是多种类型，如字符串、数值、布尔值、数组、对象或“null”。逗号分隔：对象中的键值对和数组中的值都使用逗号分隔，最后一个键值对或值后面不应有逗号。空格和换行：JSON中的空格和换行是被忽略的，可以使用它们来提高可读性。
#
# **教学：**
#
# 知识点理论讲解
#
# curl,postman,apifox在线 调用openapi操作演示，url，参数，调用方法，结果解析
#
# ## 七、开发工具简介
#
# **知识点**
#
# vscode工程目录，编辑器，内置终端，插件
#
# 1.vscode是一款跨平台的代码编辑器，支持Window，mac，Linux系统，特征是轻量化、并通过插件机制支持各种代码开发的需要。包括语法高亮（syntax high lighting），可定制的热键绑定（customizable keyboard bindings），括号匹配（bracket matching）以及代码片段收集（snippets）.为开发者提供了一个统一的开发环境。
#
# **特点:**
#
# - 轻量与高性能 - VS Code 的设计初衷是既轻量又强大，启动速度快、内存占用低，同时支持各种现代开发需求。
# - 多语言支持 - 支持几十种主流编程语言（如 JavaScript、Python、C++、Java、Go 等），并通过扩展提供更广泛的语言支持。
# - 强大的扩展系统 - 通过扩展市场，用户可以安装上千种插件（如代码美化工具、调试插件、Git 集成工具），自由定制开发环境。
# - 丰富的内置功能 - 内置 Git 控制、调试工具、终端等，帮助开发者提升效率。
# - 跨平台一致性 - 在不同操作系统上，提供一致的用户体验和功能支持。
# -
# **适用场景:**
# - 前端开发：支持 HTML/CSS/JavaScript、TypeScript，以及 React、Vue、Angular 等框架。
# - 后端开发：支持 Node.js、Python、Java 等后端开发语言。
# - 数据科学：可安装 Jupyter Notebook 插件，进行数据分析和可视化。
# - DevOps：支持 YAML 配置、Docker、Kubernetes 等工具集成。
# - 其他场景：例如文档编辑（Markdown）、静态网站生成、代码复审等。
# -
# 2.工程目录是以代码的根目录为加载点
#
# 3.内置终端，通过点击“终端”菜单，选择“新建终端” 会在右下位置打开当前开发环境所适用的终端
#
# 4.插件，在插件市场可以按照需要搜索和安装对应的插件。
