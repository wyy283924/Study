# %% [markdown]
# [SWE-bench](https://arxiv.org/abs/2310.06770)
#
# [CodeGeeX](https://arxiv.org/abs/2303.17568)
#
# [StarCoder](https://arxiv.org/abs/2305.06161)
#
# [PAL](https://arxiv.org/abs/2211.10435)
#
# [Github Copilot](https://docs.github.com/zh/copilot)
#
# [CodeGeeX2](https://github.com/THUDM/CodeGeeX2)
#
# [Github Copilot Chat](https://docs.github.com/zh/copilot/)
#
# [Inside GitHub: Working with the LLMs behind GitHub Copilot](https://github.blog/2023-05-17-inside-github-working-with-the-llms-behind-github-copilot/)
#
# [Smarter, more efficient coding: GitHub Copilot goes beyond Codex with improved AI model](https://github.blog/2023-07-28-smarter-more-efficient-coding-github-copilot-goes-beyond-codex-with-improved-ai-model/)
#
# [codex](https://arxiv.org/abs/2107.03374)
#
# [Large Language Models Meet NL2Code: A Survey](https://aclanthology.org/2023.acl-long.411/)
#
# [通义灵码](https://tongyi.aliyun.com/lingma)
#
# [讯飞星火iflycode](https://xinghuo.xfyun.cn/)
#
# [腾讯混元](https://hunyuan.tencent.com/)
#
# [公众号](https://mp.weixin.qq.com/s/aqw3xKgyjOdME7ErcuTfSA)
